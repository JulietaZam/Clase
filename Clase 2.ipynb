# %%
# %ls
# Out:
# 07_02_pie_box_scatter_bubble.ipynb  README.md         session_01/
# Canada.xlsx                         requierementsEXL  Untitled.ipynb
# datasets/                           requirements.txt  welcome_binder.ipynb
# nhanes_2015_2016.csv                runtime.txt

# %%
import pandas as pd

# %%
import numpy as np

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.tail()
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %% [markdown]
# VariableS:
#     `Age` representa la edad de cada persona, tipo de data es: `int`
#     `Gender` tipo de variables es `categorica`

# %%
dist = df['CWDistance']
dist
type(dist)
# Out:
# pandas.core.series.Series

# %%
distance = df[['CWDistance']]
distance
# Out:
#     CWDistance
# 0           79
# 1           70
# 2           85
# 3           87
# 4           72
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96
# 11          79
# 12          92
# 13          66
# 14          72
# 15         115
# 16          90
# 17          74
# 18          64
# 19          85
# 20          66
# 21         101
# 22          82
# 23          63
# 24          67

# %%
type(distance)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
ndf = df[['Age', 'Gender', 'GenderGroup','Height', 'CWDistance']]
ndf
# Out:
#     Age Gender  GenderGroup  Height  CWDistance
# 0    56      F            1   62.00          79
# 1    26      F            1   62.00          70
# 2    33      F            1   66.00          85
# 3    39      F            1   64.00          87
# 4    27      M            2   73.00          72
# 5    24      M            2   75.00          81
# 6    28      M            2   75.00         107
# 7    22      F            1   65.00          98
# 8    29      M            2   74.00         106
# 9    33      F            1   63.00          65
# 10   30      M            2   69.50          96
# 11   28      F            1   62.75          79
# 12   25      F            1   65.00          92
# 13   23      F            1   61.50          66
# 14   31      M            2   73.00          72
# 15   26      M            2   71.00         115
# 16   26      F            1   61.50          90
# 17   27      M            2   66.00          74
# 18   23      M            2   70.00          64
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# ID
# Age
# Gender
# GenderGroup
# Glasses
# GlassesGroup
# Height
# Wingspan
# CWDistance
# Complete
# CompleteGroup
# Score

# %%
col_names = df.columns
col_names
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
type(col_names)
# Out:
# pandas.core.indexes.base.Index

# %%
col_names_list = list(df.columns)
col_names_list
# Out:
# ['ID',
#  'Age',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'Wingspan',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Score']

# %%
type(col_names_list)
# Out:
# list

# %%
col_names_list.sort()
col_names_list
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %% [markdown]
# iloc = .iloc[row star: row_end, colums start: column end]
# solo usa indices

# %%
df.iloc[1:5,2:6]
# Out:
#   Gender  GenderGroup Glasses  GlassesGroup
# 1      F            1       Y             1
# 2      F            1       Y             1
# 3      F            1       N             0
# 4      M            2       N             0

# %%
df.head(6)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
# 5   6   24      M            2       N             0    75.0      71.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4
# 5          81        N              0      3

# %%
df.iloc[20:,:6]
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup
# 20  21   23      M            2       Y             1
# 21  22   29      M            2       N             0
# 22  23   25      M            2       N             0
# 23  24   26      M            2       N             0
# 24  25   23      F            1       Y             1

# %% [markdown]
# loc = .loc[row star: row_end, colums start: column end]
# solo usa nombres de columnas

# %%
df.loc[:3, ['Age', 'Gender', 'GenderGroup']]
# Out:
#    Age Gender  GenderGroup
# 0   56      F            1
# 1   26      F            1
# 2   33      F            1
# 3   39      F            1

# %%
df.tail(7)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 18  19   23      M            2       Y             1    70.0      69.0
# 19  20   24      F            1       Y             1    68.0      66.0
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 18          64        Y              1      3
# 19          85        Y              1      8
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
df.iloc[:,:-1]
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %% [markdown]
# anterior todos los renglones y ultima columna

# %% [markdown]
# saber cantidad

# %%
df.shape
# Out:
# (25, 12)

# %% [markdown]
# ultimas 3

# %%
df.iloc[:,-3:]
# Out:
#    Complete  CompleteGroup  Score
# 0         Y              1      7
# 1         Y              1      8
# 2         Y              1      7
# 3         Y              1     10
# 4         N              0      4
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6
# 11        Y              1     10
# 12        Y              1      6
# 13        Y              1      4
# 14        Y              1      9
# 15        Y              1      6
# 16        N              0     10
# 17        Y              1      5
# 18        Y              1      3
# 19        Y              1      8
# 20        N              0      2
# 21        Y              1      8
# 22        Y              1      4
# 23        Y              1      5
# 24        N              0      3

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %% [markdown]
# gender es categorica para saber cuantas categorias

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# saber que edades posibles hay

# %%
df.Age.unique()
# Out:
# array([56, 26, 33, 39, 27, 24, 28, 22, 29, 30, 25, 23, 31])

# %% [markdown]
# saber tamaño

# %%
df.groupby(['Gender', 'GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64

# %% [markdown]
# eliminar columnas, axis = 1 es para columnas

# %%
df.drop(['Complete', 'CompleteGrou'], 
    inplace = True, 
    axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_97/1281938198.py in <module>
# ----> 1 df.drop(['Complete', 'CompleteGrou'],
#       2     inplace = True,
#       3     axis = 1)
#       4 df
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
ndf= df.drop
ndf
# Out:
# <bound method DataFrame.drop of     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
ndf.head(2)
# Out:
#    Age Gender  GenderGroup  Height  CWDistance
# 0   56      F            1    62.0          79
# 1   26      F            1    62.0          70
