# %%
#Se comienza importando las librerías a utilizar
import numpy as np
import pandas as pd
import seaborn as sns; sns.set() 
import matplotlib as mpl
import matplotlib.pyplot as plt 
#import statsmodels.api as sm
from sklearn import linear_model

# %% [markdown]
# Se restablecen los gráficos a un formato oscuro

# %% [markdown]
# ## 1. ¿Cuál es la variable de interés a pronosticar?, ¿Qué se espera lograr con este proyecto?

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /srv/conda/envs/notebook/lib/python3.8/site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /srv/conda/envs/notebook/lib/python3.8/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('Libro2.xlsx',
                   engine = 'openpyxl'
                  )
df
# Out:
#          neighbourhood property_type        room_type  accommodates  \
# 0           Roma Norte     Apartment  Entire home/apt             5
# 1    Centro HistÃ³rico     Apartment  Entire home/apt             5
# 2              Polanco     Apartment  Entire home/apt             2
# 3              Polanco     Apartment  Entire home/apt             5
# 4              Polanco     Apartment     Private room             1
# ..                 ...           ...              ...           ...
# 195         Roma Norte          Loft  Entire home/apt             2
# 196          Zona Rosa          Loft  Entire home/apt             2
# 197         Roma Norte          Loft     Private room             2
# 198  Centro HistÃ³rico          Loft     Private room             2
# 199           Roma Sur          Loft      Shared room             1
#
#      bathrooms  bedrooms  beds  bed_type  price  minimum_nights  \
# 0          2.0         2     3  Real Bed   3503               3
# 1          2.0         2     2  Real Bed   3923               3
# 2          1.5         1     1  Real Bed    500               3
# 3          2.5         3     3  Real Bed   3600               3
# 4          0.0         1     1  Real Bed    401               3
# ..         ...       ...   ...       ...    ...             ...
# 195        1.5         1     1  Real Bed    909               2
# 196        1.5         1     1  Real Bed   1500               2
# 197        1.5         1     1  Real Bed    498               1
# 198        2.0         1     1  Real Bed    542               1
# 199        1.0         1     1  Real Bed    227               2
#
#      availability_365  calculated_host_listings_count  reviews_per_month
# 0                 338                               3               2.77
# 1                  61                               3               2.64
# 2                   0                               3               0.12
# 3                   0                               3               0.05
# 4                 365                               2               0.27
# ..                ...                             ...                ...
# 195                80                               1               3.64
# 196                 0                               1               0.70
# 197               365                               2               3.10
# 198               364                               1               1.03
# 199                90                              18               0.05
#
# [200 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood                   200 non-null    object
#  1   property_type                   200 non-null    object
#  2   room_type                       200 non-null    object
#  3   accommodates                    200 non-null    int64
#  4   bathrooms                       200 non-null    float64
#  5   bedrooms                        200 non-null    int64
#  6   beds                            200 non-null    int64
#  7   bed_type                        200 non-null    object
#  8   price                           200 non-null    int64
#  9   minimum_nights                  200 non-null    int64
#  10  availability_365                200 non-null    int64
#  11  calculated_host_listings_count  200 non-null    int64
#  12  reviews_per_month               200 non-null    float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 20.4+ KB

# %%
df.describe()
# Out:
#        accommodates   bathrooms   bedrooms        beds        price  \
# count    200.000000  200.000000  200.00000  200.000000    200.00000
# mean       3.210000    1.627500    1.52000    1.745000   2080.75000
# std        2.313582    0.856541    1.19446    1.445831   2098.45721
# min        1.000000    0.000000    0.00000    0.000000    181.00000
# 25%        2.000000    1.000000    1.00000    1.000000    499.50000
# 50%        2.000000    1.500000    1.00000    1.000000   1500.00000
# 75%        4.000000    2.000000    2.00000    2.000000   2974.00000
# max       15.000000    6.500000    7.00000   11.000000  13294.00000
#
#        minimum_nights  availability_365  calculated_host_listings_count  \
# count      200.000000        200.000000                      200.000000
# mean         6.200000        228.225000                        5.445000
# std         11.887242        138.435277                        7.152817
# min          1.000000          0.000000                        1.000000
# 25%          2.000000         90.000000                        2.000000
# 50%          3.000000        270.000000                        3.000000
# 75%          4.250000        364.000000                        6.000000
# max        120.000000        365.000000                       41.000000
#
#        reviews_per_month
# count         200.000000
# mean            1.234250
# std             1.324609
# min             0.020000
# 25%             0.340000
# 50%             0.705000
# 75%             1.785000
# max             8.360000

# %%
df['price'].plot(kind = 'hist')
plt.title('Histograma de la variable price', fontsize = 15) 
plt.show()

# %%
df['accommodates'].plot(kind = 'hist')
plt.title('Histograma de la variable accommodates', fontsize = 15) 
plt.show()

# %%
variables = ['neighbourhood', 'property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'bed_type', 'price', 'minimum_nights',
       'availability_365', 'calculated_host_listings_count',
       'reviews_per_month']
df = df[variables].dropna() 
df[variables].corr()
# Out:
#                                 accommodates  bathrooms  bedrooms      beds  \
# accommodates                        1.000000   0.752231  0.749474  0.905426
# bathrooms                           0.752231   1.000000  0.649517  0.724312
# bedrooms                            0.749474   0.649517  1.000000  0.772601
# beds                                0.905426   0.724312  0.772601  1.000000
# price                               0.972455   0.704977  0.724498  0.891613
# minimum_nights                     -0.041367   0.019199 -0.013732 -0.048477
# availability_365                   -0.063174   0.045865 -0.098171 -0.072194
# calculated_host_listings_count      0.037748  -0.018330 -0.028397  0.011999
# reviews_per_month                   0.080005   0.039714 -0.091254  0.013609
#
#                                    price  minimum_nights  availability_365  \
# accommodates                    0.972455       -0.041367         -0.063174
# bathrooms                       0.704977        0.019199          0.045865
# bedrooms                        0.724498       -0.013732         -0.098171
# beds                            0.891613       -0.048477         -0.072194
# price                           1.000000       -0.050461         -0.076643
# minimum_nights                 -0.050461        1.000000         -0.029501
# availability_365               -0.076643       -0.029501          1.000000
# calculated_host_listings_count  0.033813        0.045874         -0.050373
# reviews_per_month               0.056343       -0.087386          0.049519
#
#                                 calculated_host_listings_count  \
# accommodates                                          0.037748
# bathrooms                                            -0.018330
# bedrooms                                             -0.028397
# beds                                                  0.011999
# price                                                 0.033813
# minimum_nights                                        0.045874
# availability_365                                     -0.050373
# calculated_host_listings_count                        1.000000
# reviews_per_month                                     0.168840
#
#                                 reviews_per_month
# accommodates                             0.080005
# bathrooms                                0.039714
# bedrooms                                -0.091254
# beds                                     0.013609
# price                                    0.056343
# minimum_nights                          -0.087386
# availability_365                         0.049519
# calculated_host_listings_count           0.168840
# reviews_per_month                        1.000000

# %%
sns.lmplot(x = 'accommodates', y = 'price', data = df) 
plt.title('Diagrama de dispersión', fontsize = 15) 
plt.show()

# %%
sns.boxplot(data = df.loc[:,'price'])

# %%
sns.boxplot(data = df.loc[:,'accommodates'])

# %%
sns.boxplot(data = df.loc[:,['accommodates','price']])
