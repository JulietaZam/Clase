# %% [markdown]
# ## Parte dos semana 4 clase 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   pokemon.csv
# antropometria00.csv        data.csv       sample_pivot.csv
# antropometria-dataset.csv  headbrain.csv  tips.csv
# Canada.xlsx                mic.xlsx       weight-height.csv
# Cartwheeldata.csv          movies.csv

# %% [markdown]
# ## HAY RELACION ENTRE LA Head Size Y Brain Weight

# %%
df = pd.read_csv('datasets/headbrain.csv')

X = df['Head Size(cm^3)']
Y = df['Brain Weight(grams)']
df.head()

np.corrcoef(X,Y)
# Out:
# array([[1.        , 0.79956971],
#        [0.79956971, 1.        ]])

# %% [markdown]
# ## conclusion

# %% [markdown]
# los coeficientes de correlacion es de 0.79, entonces si existe una relacion muy fuerte entre estas variables

# %%
#colors = (1:'red', 2:'green')

#plt.figure(figsize = (13,8)

plt.scatter(x,Y,
           c = df['Gender'],
           marker = 'x',
           s = 75)

plt.xlabel('Head Size(cm^3)', fontweight = 'regular', color = 'black') 
           #fontzise = 18)
# Out:
# Text(0.5, 0, 'Head Size(cm^3)')

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import statsmodels.api as sm 
import statsmodels.formula.api as smf

# %%
model = sm.OLS.from_formula('Y~X', 
                            data = df)
result = model.fit()
result.summary
# Out:
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x7f23ea228640>>
