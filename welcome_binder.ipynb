# %% [markdown]
# # Clase 1: Pasos basicos

# %% [markdown]
# ## We need `seaborn`, which shall be included it in `requirements.txt` file

# %% [markdown]
# Texto instrucciones, hay que seleccionar Markdown

# %%
print('hola')

# %%
# %ls

# %%
# %magic

# %%
nombre = 'my Name'
nombre
# Out:
# 'my Name'

# %%
# %pwd
# Out:
# '/home/jovyan'

# %%
import numpy as np

# %%
N = 50
x = np.random.rand(N)
x
# Out:
# array([0.28222788, 0.74546016, 0.9832593 , 0.99166956, 0.59299361,
#        0.20359876, 0.98975806, 0.97391689, 0.17506828, 0.54697602,
#        0.4840964 , 0.26449874, 0.60232224, 0.3476562 , 0.06860903,
#        0.2687947 , 0.02823856, 0.0739616 , 0.89348761, 0.90890126,
#        0.02720546, 0.26449254, 0.31202074, 0.02862507, 0.56113087,
#        0.9028232 , 0.77504079, 0.3687627 , 0.25576482, 0.72364404,
#        0.00662011, 0.00318503, 0.16028663, 0.61092683, 0.33632113,
#        0.4436587 , 0.38500807, 0.25018303, 0.89831452, 0.53135288,
#        0.52746831, 0.60916825, 0.95304037, 0.08638769, 0.37607544,
#        0.7248923 , 0.85590323, 0.57823087, 0.37495542, 0.47212002])

# %% [markdown]
# # Typos de data en Python

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type (4.0)
# Out:
# float

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(nombre)
# Out:
# str

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(-3)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(2/3)
# Out:
# float

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
sum(numbers)
# Out:
# 15

# %%
suma = sum(numbers)
suma
# Out:
# 15

# %%
lenghtNumbers = len(numbers)
lenghtNumbers
# Out:
# 5

# %%
type(numbers)
# Out:
# list

# %%
promedio = suma/lenghtNumbers
promedio
# Out:
# 3.0

# %%
# 60 * 10^(-2) = 60 * (10/100) = 60 * 0.1 = 6
60*10**(-2)
# Out:
# 0.6

# %%
type (bool('yes'))
# Out:
# bool

# %%
type('yes')
# Out:
# str

# %%
type(6<5)
# Out:
# bool

# %%
a_list = [True, 6<5, 1==3, None is None, 2, 'Name', 4.0, 2/3]
a_list
# Out:
# [True, False, False, True, 2, 'Name', 4.0, 0.6666666666666666]

# %%
x = 5
y = 6 
if x<y:
    print ('{} es menor que {}' .format(x,y))
else:
    print ('{} es mayor que {}' .format(x,y))
# Out:
# 5 es menor que 6

# %%
if x<y:
    print(x,'es menor que', y)
# Out:
# 5 es menor que 6
